# %%
import pandas as pd

ColinsWeatherData=pd.read_csv('Canadian_climate_history (1970-2020).csv
')
                              ColinsWeatherData
# Out:
#   File "<ipython-input-1-f26e01dd291d>", line 3
#     ColinsWeatherData=pd.read_csv('Canadian_climate_history (1970-2020).csv
#                                                                            ^
# SyntaxError: EOL while scanning string literal

# %%
import pandas as pd
ColinsWeatherData=pd.read_csv('Canadian_climate_history (1970-2020).csv')
ColinsWeatherData
# Out:
#            LOCAL_DATE  MEAN_TEMPERATURE_CALGARY  TOTAL_PRECIPITATION_CALGARY  \
# 0        1/1/70 00:00                      -5.8                          1.3
# 1        1/2/70 00:00                      -3.7                          0.0
# 2        1/3/70 00:00                      -7.8                          1.0
# 3        1/4/70 00:00                     -16.1                          1.3
# 4        1/5/70 00:00                     -20.9                          0.3
# ...               ...                       ...                          ...
# 18258  12/28/19 00:00                      -7.7                          0.0
# 18259  12/29/19 00:00                      -3.3                          0.0
# 18260  12/30/19 00:00                      -1.6                          0.0
# 18261  12/31/19 00:00                       4.3                          0.0
# 18262    1/1/20 00:00                      -0.3                          0.0
#
# ...

# %%
import pandas as pd
ColinsWeatherData=pd.read_csv('c/Users/Documents/Data\ 301/Course\ Project/Canadian_climate_history\ (1970-2020)')
ColinsWeatherData
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-90a0a9877d48> in <module>
#       1 import pandas as pd
# ----> 2 ColinsWeatherData=pd.read_csv('c/Users/Documents/Data\ 301/Course\ Project/Canadian_climate_history\ (1970-2020)')
#       3 ColinsWeatherData
#
# ...

# %%
import pandas as pd
ColinsWeatherData=pd.read_csv('c/Users/Documents/Data 301/Course Project/course-project-group_1012/DATA/Raw/Canadian_climate_history (1970-2020).')
ColinsWeatherData
